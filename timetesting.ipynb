# %%
def test1():
    for i in range(900):
        5**i
    print("Hello")
    for i in range(100):
        5**i
        
def test2():
    for i in range(1000):
        5**i
        if i == 100:
            print("Hello")

# %%
# %timeit test1()
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %%
# %timeit test2()
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %%
def test3():
    for i in range(1000):
        5**i

def test4():
    for i in list(range(1000)):
        5**i

# %%
# %timeit test3()
# %timeit test4()
# Out:
# 796 μs ± 47.9 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 750 μs ± 19.3 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
balance = 0
total = 0

def command(a, b, c):
    global total
    global balance
    total += c
    balance += c
    
def recv_osc():
    global balance
    balance -= 1
    
events_in_buffer = 99
events_per_loop = 3001
total_events = 100010

total_events -= events_in_buffer

number_of_complete_loops = total_events // events_per_loop
number_of_events_in_last_loop = total_events % events_per_loop

command(31, 0, events_in_buffer)
for i in range(number_of_complete_loops):
    command(31, 0, events_per_loop)
    for j in range(events_per_loop):
        recv_osc()
command(31, 0, number_of_events_in_last_loop)
for j in range(events_in_buffer + number_of_events_in_last_loop):
    recv_osc()
        
print(total)
print(balance)
# Out:
# 100010
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load("test.npy")

# %%
for i in range(100):
    plt.plot(data[i][0])
plt.show()
